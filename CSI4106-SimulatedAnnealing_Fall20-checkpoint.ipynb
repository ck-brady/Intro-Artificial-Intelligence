# %% [markdown]
# # Notebook 3 - Simulated annealing for the TSP

# %% [markdown]
# CSI4106 Artificial Intelligence
# Fall 2020
# Prepared by Julian Templeton and Caroline Barrière

# %% [markdown]
# ***INTRODUCTION***:
#
# This homework will allow you to look deeper into one of the randomized searches presented in class, that of *Simulated Annealing*. It is a good example of a *random modification* algorithm, in which we start with a greedy solution, and then make changes and accept the modified solutions with different probabilities given their level of fitness to a cost function.
#
# The application domain for experimenting with *Simulated Annealing* is the traveling salesman problem (TSP), which is a classical problem of scheduling, with optimization on the cost of travel.
#
# The notebook will lead into the **Simulated Annealing** portion after exploring a **greedy approach** and a **randomized greedy approach**.

# %% [markdown]
# ***HOMEWORK***:
# Go through the notebook by running each cell, one at a time.
# Look for **(TO DO)** for the tasks that you need to perform. Do not edit the code outside of the questions which you are asked to answer unless specifically asked. Once you're done, sign the notebook (see the added step at the end), and submit it.
#
# *The notebook will be marked on 20.
# Each **(TO DO)** has a number of points associated with it.*
# ***

# %% [markdown]
# **1. Let's start with a small set of cities.**

# %%
# let's define 5 cities with a label and a (x,y) coordinate
cities = {'A': (0,0), 'B': (1,1), 'C': (1,0), 'D': (1,-1), 'E': (-1,-1)}

# %% [markdown]
# Let's plot the nodes using the *showNodes* method below.
# The packages matplotlib, networkx, and numpy must be installed first.
# To do so, open a command prompt and type **pip install numpy** and **pip install networkx** (If you are using linux or potentially Mac, you may need to use **pip3** rather than **pip** depending on how you set it up). You should already have matplotlib, but if not use the pip command **pip install matplotlib**. After installing the packages, run the cell below. If it does not work, restart the Kernel and run through it again to be able to run the cell.

# %%
import matplotlib.pyplot as plt
import networkx as nx

# small method to show nodes
# provide defaults for figure size (size), as well as x and y axis
def showNodes(nodeDict, size= (6.5, 4), xLim=[-2,2], yLim=[-2,2]):
    fig = plt.figure(figsize=size)
    axg = fig.add_subplot(111)
    axg.set_xlim(xLim)
    axg.set_ylim(yLim)

    G=nx.Graph()
    for k in nodeDict.keys():
        G.add_node(k, coor=nodeDict.get(k))
    
    pos=nx.get_node_attributes(G,'coor')
    nx.draw(G, pos, with_labels = True)
    plt.axis('on')
    plt.show()

# %%
# show the cities on a map
showNodes(cities)

# %% [markdown]
# #### 2. Let's find the distances between all cities.
# First, we define a method to calculate the distance between two specific cities, and then a method to find the distances between all pairs of nodes.

# %%
import math

# returns the euclidian distance between two nodes
def dist(node1, node2):
    return round(math.sqrt(math.pow(node1[0] - node2[0], 2) + math.pow(node1[1] - node2[1], 2)), 3)

# %%
# Small test to see the distance
dist(cities.get('A'), cities.get('B'))
# Out:
# 1.414

# %%
# building a dictionary of all pairs or distances
def distDict(nodes):
    distance = {}
    # go through all pairs of nodes
    for k in nodes.keys():
        for m in nodes.keys():
            distance[k,m] = dist(nodes.get(k), nodes.get(m))
    return distance

# %%
# showing the distances between the cities
distances = distDict(cities)
print(distances)
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0}

# %%
# find the min distance from node1 to all other nodes.
# it receives the node1 label, the labels of other nodes to test,
# and the precalculated distances between all nodes
def closestNode(node1_label, otherNodes_Labels, distanceDict):
    # tricky syntax... it creates tuples where the distance is the first element of the tuple
    # and the position in the array is the second element of the tuple
    minDist = min( (distanceDict[node1_label,k], k) for k in otherNodes_Labels)
    # get the second element of the tuple which is the index found
    foundNode = minDist[1]
    return foundNode

# %%
# Testing the closest node
closestNode('B', ['C', 'D'], distances)
# Out:
# 'C'

# %% [markdown]
# #### 3. Greedy solution first
# Before we can apply *simulated annealing*, we must first find a suboptimal solution that we will refine. The first solution will be a Greedy solution. Only the choice of the starting node is random in this solution, and from there, the algorithm always choses the closest node.

# %%
# greedy solution
import random

def greedy_solution(nodes):
    # distance matrix
    allDist = distDict(nodes)
    # pick a first node at random among the set of keys (node names)
    cur_node = random.choice(list(nodes.keys()))
    # add that node to solution
    solution = [cur_node]
    # build a free list of nodes (not yet used) containing all nodes except the one just chosen 
    free_list = list(nodes.keys())
    free_list.remove(cur_node)
    
    # while there are still nodes to be attached
    while free_list:
        # find the closestNode
        found_node = closestNode(cur_node, free_list, allDist)
        cur_node = found_node
        free_list.remove(cur_node)
        solution.append(cur_node)

    return solution

# %%
# Test obtaining a greedy solution
gs = greedy_solution(cities)
print(gs)
# Out:
# ['B', 'C', 'A', 'D', 'E']

# %% [markdown]
# #### 4. Showing a path.
# We slightly modify to showNodes method from before, to become showPath, wich is now a directed graph.

# %%
# small method to show a path
# it receives an ordered list of nodes e.g. ['B','C','A', 'D', 'E']
# and a dictionary of all the nodes and their positions
def showPath(path, nodeDict, size= (6.5, 4), xLim=[-2,2], yLim=[-2,2]):
    fig = plt.figure(figsize=size)
    axg = fig.add_subplot(111)
    axg.set_xlim(xLim)
    axg.set_ylim(yLim)

    G=nx.DiGraph()
    for k in path:
        G.add_node(k, pos=nodeDict.get(k))
        
    for i in range(len(path) - 1):
        x = path[i]
        y = path[i + 1]
        G.add_edge(x,y)
        
    pos=nx.get_node_attributes(G,'pos')
    nx.draw(G, pos, with_labels = True, edge_color = 'b', arrows=True)   
    # nx.draw(G, pos, with_labels = True)
    plt.axis('on')
    plt.show()

# %% [markdown]
# **(TO DO) Q1 - 2 marks**
# 1. Select a seed (integer) to use in the cell below
# 2. Run that cell to set the seed (only once)
# 3. Run the tests below the seed declaration repeatedly (just manually run it) until you get two identical results in the same run. Record how many runs it took and the solution found in the answer section below.
# 4. Run the tests below the seed declaration repeatedly (just manually run it) until you get two different results in the same run. Record how many runs it took and the solution found in the answer section below.

# %% [markdown]
# **(ANSWER in this Markdown) Q1**
# Nb of runs needed to generate an identical gs1 and gs2 :  4
# Solution generated for the identical gs1 and gs2 : ['A', 'C', 'B', 'D', 'E']
#
# Nb of runs needed to generate a different gs1 and gs2 :  1
# Solutions generated for the distinct gs1 and gs2 : ['A', 'C', 'B', 'D', 'E'], ['D', 'C', 'A', 'B', 'E']

# %% [markdown]
# Setup the seed:

# %%
# To Do: Place your seed here and run the cell to set/reset it
# random.seed(int)
random.seed(4)

# %% [markdown]
# Let us run a test to visualize two greedy solutions. Look at the text output of the path if the plotted graph contains edges that go through a node.

# %%
# To Do: Need to run this (make no changes) and answer the questions above

# Testing to output the path chosen by the greedy solution
gs1 = greedy_solution(cities)
print(gs1)
showPath(gs1, cities)
gs2 = greedy_solution(cities)
print(gs2)
showPath(gs2, cities)
# Out:
# ['B', 'C', 'A', 'D', 'E']
# ['C', 'A', 'B', 'D', 'E']

# %% [markdown]
# **(TO DO) Q2 - 2 marks**
# Complete the method to find the total length of the path found.

# %%
# (TO DO) totalDistance, which receives a path (list of node labels) and the dictionary of distances
def totalDist(path, distanceDict):
    total = 0
    for i in range(len(path) - 1):
        x = path[i]
        y = path[i+1]
        total += distanceDict.get((x,y))
    return round(total,3)

# %%
# Test the total distance method
print(totalDist(gs1, distances))
print(totalDist(gs2, distances))
# Out:
# 5.414
# 6.414

# %% [markdown]
# **(TO DO) Q3 - 4 marks**
# Add two more cities (wherever you want within the predefined -2 to +2 axis as long as no other node is already there).  Rerun the full sequence of tasks performed above on the larger set of cities that you will define below: (1) defining the graph (2) showing the points (3) building the distance dictionary, (4) finding two unique greedy solutions, (5) showing the different paths found along with their total distances.

# %%
# (1) Defining a larger set of cities  (add two more)
moreCities = {'A': (0,0), 'B': (1,1), 'C': (1,0), 'D': (1,-1), 'E': (-1,-1), 'F': (-1,1.5), 'G': (-1.5,1)}
# (2) Show the points
showNodes(moreCities)
# (3) Build the distance dictionary
moreDistances = distDict(moreCities)
print(moreDistances)
# (4) Find two unique greedy solutions 
solution1 = greedy_solution(moreCities)
solution2 = greedy_solution(moreCities)
# (5) Show the two unique paths found above along with their total distances
showPath(solution1, moreCities)
print(solution1)
print(totalDist(solution1, moreDistances))
showPath(solution2, moreCities)
print(solution2)
print(totalDist(solution2, moreDistances))
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('A', 'F'): 1.803, ('A', 'G'): 1.803, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('B', 'F'): 2.062, ('B', 'G'): 2.5, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('C', 'F'): 2.5, ('C', 'G'): 2.693, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('D', 'F'): 3.202, ('D', 'G'): 3.202, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0, ('E', 'F'): 2.5, ('E', 'G'): 2.062, ('F', 'A'): 1.803, ('F', 'B'): 2.062, ('F', 'C'): 2.5, ('F', 'D'): 3.202, ('F', 'E'): 2.5, ('F', 'F'): 0.0, ('F', 'G'): 0.707, ('G', 'A'): 1.803, ('G', 'B'): 2.5, ('G', 'C'): 2.693, ('G', 'D'): 3.202, ('G', 'E'): 2.062, ('G', 'F'): 0.707, ('G', 'G'): 0.0}
# ['G', 'F', 'A', 'C', 'B', 'D', 'E']
# 8.51
# ['A', 'C', 'B', 'D', 'E', 'G', 'F']
# 8.769

# %% [markdown]
# **5. Randomized Greedy - Setup**
#
# Before we create our Randomized Greedy solution, we will define a new function called kClosestNodes that will return the k-closest nodes to a given node.

# %%
# find the min distance from node1 to all other nodes.
# it receives the node1 label, the labels of other nodes to test,
# the precalculated distances between all nodes, and k for how many to return
# The function then outputs a list of the k-closest nodes, where the
# first is the closest and the kth is the kth-closest
def kClosestNodes(node1_label, otherNodes_Labels, distanceDict, k):
    kClosest = []
    # Create a sorted distance list based on the values from the distance dictionary
    # This has the form [((node_1, node_2),value_1), ..., ((node_n, node_n), value_n)]
    sortedDistances = sorted(distanceDict.items(), key=lambda keyPair: keyPair[1])
    # Iterate through the sorted distance list to find our k min distances
    # from node1_label
    for key, value in sortedDistances:
        if (k > 0 and key[0] == node1_label and key[1] in otherNodes_Labels):
            k -= 1
            kClosest.append(key[1])
    return kClosest

# %%
# Example usage
# View the distance dictionary to verify correctness when finding the closest nodes
# to node B in cities
print(distances)
# Find the two closest nodes to the node B in cities (using its distance dictionary)
kClosestNodes('B', ['A', 'C', 'D', 'E'], distances, 2)
# Out:
# {('A', 'A'): 0.0, ('A', 'B'): 1.414, ('A', 'C'): 1.0, ('A', 'D'): 1.414, ('A', 'E'): 1.414, ('B', 'A'): 1.414, ('B', 'B'): 0.0, ('B', 'C'): 1.0, ('B', 'D'): 2.0, ('B', 'E'): 2.828, ('C', 'A'): 1.0, ('C', 'B'): 1.0, ('C', 'C'): 0.0, ('C', 'D'): 1.0, ('C', 'E'): 2.236, ('D', 'A'): 1.414, ('D', 'B'): 2.0, ('D', 'C'): 1.0, ('D', 'D'): 0.0, ('D', 'E'): 2.0, ('E', 'A'): 1.414, ('E', 'B'): 2.828, ('E', 'C'): 2.236, ('E', 'D'): 2.0, ('E', 'E'): 0.0}
# ['C', 'A']

# %% [markdown]
# **6. Randomized Greedy**
#
# Next you will find another suboptimal solution that we will refine. This second solution will be a Randomized Greedy solution.

# %% [markdown]
# **(TO DO) Q4 - 5 marks**
# The Randomized Greedy solution that you will create still selects a random first node, but should now pick randomly among the k closest nodes available, given a probability distribution (rather than the closest node).
#
# For example, if you found the five closest nodes when looking for which to add next, you would randomly choose one of them where the closest nodes would have a higher probability of being chosen then the nodes that are not as close.
#
# The probability distribution for a set of node distances is given by the function *normalize* below and finding the k-closest nodes is given from the kClosestNodes function above. You must call both of these functions in your solution and follow the general structure defined by the comments.
#
# After finishing the function, add one more test to the tests below with a different value for k

# %%
import random
import numpy as np

# DO NOT EDIT THIS FUNCTION
# nodeFrom is the node we start at, nodesTo is a list of nodes
# that nodeFrom can go to, and distDict is the dictionary of all
# combinations of distances.
# This provides the probability distribution to be used by
# randomized_greedy_solution
def normalize(nodeFrom, nodesTo, distDict):
    distances = []
    # Here we normalize by 1/distance^2 
    for nodeTo in nodesTo:
        distances.append(1 / distDict[nodeFrom, nodeTo] ** 2)
    sumOfDistances = sum(distances)
    normalizedDistances = [dist / sumOfDistances for dist in distances]
    return normalizedDistances
    
# k represents the number of closest nodes to be returned from the
# function kClosestNodes
def randomized_greedy_solution(nodes, k):
    # distance matrix
    allDist = distDict(nodes)
    # pick a first node at random among the set of keys (node names)
    cur_node = random.choice(list(nodes.keys()))
    # add that node to solution
    solution = [cur_node]
    # build a free list of nodes (not yet used) containing all nodes except the one just chosen 
    free_list = list(nodes.keys())
    free_list.remove(cur_node)
    
    # while there are still nodes to be attached
    while free_list:
        
        # TO DO START: Complete the algorithm by performing what the comments ask
        
        # Get the closest nodes
        closest_nodes = kClosestNodes(cur_node, free_list, allDist, k)
        # Find the normalized distances
        normalized_distances = normalize(cur_node, closest_nodes, allDist)
        # Select a random closest node based on the probabilities found by the normalized distances
        # You will use the function np.random.choice(options, list_of_probabilities_for_options)
        # For more information on np.random.choice check out the official documentation:
        #      https://docs.scipy.org/doc/numpy-1.15.0/reference/generated/numpy.random.choice.html#numpy.random.choice
        print(closest_nodes)
        found_node = np.random.choice(closest_nodes, p=normalized_distances)
        # Print out the probabilities for each closest node choice (just output both lists saying what they are)
        print("Probabilities of closest nodes:", normalized_distances)
        # Print out the closest node selected by the probability distribution with it's probability of being selected
        print("Closest node selected:", found_node)
        # TO DO END
        
        # Same as in the Greedy approach
        cur_node = found_node
        free_list.remove(cur_node)
        solution.append(cur_node)

    return solution

# %%
# Testing to output the path chosen by the randomized greedy solution with various k's to the greedy solution
# Run a few times to see how the results differ with the non-deterministic Randomized Greedy solution
# Note that if they start with the same node and k=1 that the results of both will be the same
print("Greedy Test")
gr = greedy_solution(moreCities)
print(gr)
print(totalDist(gr, moreDistances))
showPath(gr, moreCities)
print("Randomized Greedy Test")
rgs1 = randomized_greedy_solution(moreCities, 1)
print(rgs1)
print(totalDist(rgs1, moreDistances))
showPath(rgs1, moreCities)
print("Randomized Greedy Test")
rgs2 = randomized_greedy_solution(moreCities, 2)
print(rgs2)
print(totalDist(rgs2, moreDistances))
showPath(rgs2, moreCities)
# TO DO: Add one more test randomized_greedy_solution with a different k
# ...
# Out:
# Greedy Test
# ['F', 'G', 'A', 'C', 'B', 'D', 'E']
# 8.51
# Randomized Greedy Test
# ['F']
# Probabilities of closest nodes: [1.0]
# Closest node selected: F
# ['A']
# Probabilities of closest nodes: [1.0]
# Closest node selected: A
# ['C']
# Probabilities of closest nodes: [1.0]
# Closest node selected: C
# ['B']
# Probabilities of closest nodes: [1.0]
# Closest node selected: B
# ['D']
# Probabilities of closest nodes: [1.0]
# Closest node selected: D
# ['E']
# Probabilities of closest nodes: [1.0]
# Closest node selected: E
# ['G', 'F', 'A', 'C', 'B', 'D', 'E']
# 8.51
# Randomized Greedy Test
# ['F', 'A']
# Probabilities of closest nodes: [0.8667303177202507, 0.13326968227974928]
# Closest node selected: F
# ['A', 'B']
# Probabilities of closest nodes: [0.5667120683843435, 0.43328793161565654]
# Closest node selected: A
# ['C', 'B']
# Probabilities of closest nodes: [0.6665995420411309, 0.3334004579588691]
# Closest node selected: C
# ['B', 'D']
# Probabilities of closest nodes: [0.5, 0.5]
# Closest node selected: D
# ['B', 'E']
# Probabilities of closest nodes: [0.5, 0.5]
# Closest node selected: E
# ['B']
# Probabilities of closest nodes: [1.0]
# Closest node selected: B
# ['G', 'F', 'A', 'C', 'D', 'E', 'B']
# 9.338

# %% [markdown]
# **7. Defining the process of simulated annealing**
# The class below defines the simulated annealing process.  This class is an adaptation of the class anneal.py found in the python code provided in this github https://github.com/chncyhn/simulated-annealing-tsp. You are not asked to changed this class, just go through it and try to understand it so as to get a better understanding of the *simulated annealing* algorithm.

# %%
# class to perform a simulated annealing
# must start with a set of nodes, all other parameters have defaults
class SimAnneal(object):
    def __init__(self, nodes, randomizedGreedy, k=4, T=-1, alpha=-1, stopping_T=-1, stopping_iter=-1):
        # set of nodes
        self.nodes = nodes
        # number of nodes
        self.N = len(nodes)
        # set the temperature T to sqrt(N) if not specified
        self.T = math.sqrt(self.N) if T == -1 else T
        # set alpha (rate at which the temperature is decreased)
        self.alpha = 0.995 if alpha == -1 else alpha
        # set stopping temprature
        self.stopping_temperature = 0.00000001 if stopping_T == -1 else stopping_T
        # set stopping iteration
        self.stopping_iter = 100000 if stopping_iter == -1 else stopping_iter
        # start at iteration 1
        self.iteration = 1

        # calculate the distances
        self.allDist = distDict(nodes)
        
        # start with greedy solution if randomizedGreedy is false,
        #  start with the randomized greedy solution if randomizedGreedy is true
        if (randomizedGreedy):
            self.cur_solution = randomized_greedy_solution(nodes, k)
            self.improvementMessage = 'Improvement over randomized greedy heuristic: '
        else:
            self.cur_solution = greedy_solution(nodes)
            self.improvementMessage = 'Improvement over greedy heuristic: '
        
        # so far, the best solution is the one we have
        self.best_solution = list(self.cur_solution)

        # calculate fitness of the current solution
        self.cur_fitness = self.fitness(self.cur_solution)
        # initial fitness for initial solution
        self.initial_fitness = self.cur_fitness
        # best fitness so far
        self.best_fitness = self.cur_fitness
        # build the fitness list as we explore solutions
        self.fitness_list = [self.cur_fitness]


    def fitness(self, sol):
        """ Objective value of a solution """
        return totalDist(sol, self.allDist)

    # acceptance propability
    def p_accept(self, candidate_fitness):
        """
        Probability of accepting if the candidate is worse than current
        Depends on the current temperature and difference between candidate and current
        """
        return math.exp(-abs(candidate_fitness - self.cur_fitness) / self.T)

    def accept(self, candidate):
        """
        Accept with probability 1 if candidate is better than current
        Accept with probabilty p_accept(..) if candidate is worse
        """
        candidate_fitness = self.fitness(candidate)
        # test if fitness is smaller then the current one
        if candidate_fitness < self.cur_fitness:
            self.cur_fitness = candidate_fitness
            self.cur_solution = candidate
            # test if fitness is better than best so far, keep it as best if so
            if candidate_fitness < self.best_fitness:
                self.best_fitness = candidate_fitness
                self.best_solution = candidate

        # if solution is worst than the current one, there is still a possibility to pursue it
        else:
            if random.random() < self.p_accept(candidate_fitness):
                self.cur_fitness = candidate_fitness
                self.cur_solution = candidate

    def anneal(self):
        """
        Execute simulated annealing algorithm
        """
        # go through the temperature schedule
        print(self.T)
        print(self.stopping_temperature)
        while (self.T >= self.stopping_temperature) and (self.iteration < self.stopping_iter):
            # explore current solution
            candidate = list(self.cur_solution)
            # modify the solution to switch two cities
            # first chosen city between [2,N-1] - not changing the first city
            l = random.randint(2, self.N - 1)
            # second city between [0,N-1] Not sure why ??
            i = random.randint(0, self.N - l)
            # the chosen nodes are switch
            candidate[i:(i + l)] = reversed(candidate[i:(i + l)])
            # perform acceptance test 
            self.accept(candidate)
            # multiply the temperature by alpha (this will reduce it)
            self.T *= self.alpha
            self.iteration += 1
            
            # add current fitness to list (to be able to display)
            self.fitness_list.append(self.cur_fitness)

        print('Best fitness obtained: ', self.best_fitness)
        print(self.improvementMessage,
              round((self.initial_fitness - self.best_fitness) / (self.initial_fitness), 4))

        return self.best_solution
    
    def plot_learning(self):
        """
        Plot the fitness through iterations
        """
        plt.plot([i for i in range(len(self.fitness_list))], self.fitness_list)
        plt.ylabel('Fitness')
        plt.xlabel('Iteration')
        plt.show()

# %% [markdown]
# #### 8. Refining a greedy solution through simulated annealing.

# %% [markdown]
# **(TO DO) Q5 - 5 marks**
# Put comments in the code below explaining what it does.  Also run it a few times.  It will show you how there can be improvement (or not) from the greedy solution and randomized greedy solution to the annealed one.

# %%
firstSol = greedy_solution(moreCities)   # generate a greedy search solution.   
distances = distDict(moreCities)         # generate the distances between each node, for use in calculating total distance of the path. 
print('Solution {} takes a total of {}'.format(firstSol,totalDist(firstSol, distances))) # calculate total distance. 
showPath(firstSol, moreCities)           # print results of solution path. 

sa = SimAnneal(moreCities, False)        # creates/sets an annealing object, False refers to greedy search as the underlying searching algorithm that will be modifide using annealing algorithm. 
betterSol = sa.anneal()                  # run the annealing algoirthm on the object, store the result in var. it will generate candidate soltuion chosen based on an increasingly large cut off probability, then choose the best solution. 
showPath(betterSol, moreCities)          # shows the solution path generated using greedy search with annealing and performance metric. 

secondSol = randomized_greedy_solution(moreCities, 4)   # generate a randomized greedy solution, using k=4 closest nodes. 
print('Solution {} takes a total of {}'.format(secondSol,totalDist(secondSol, distances))) # get total distance and show. 
showPath(secondSol, moreCities)          # show solution path. 

sa2 = SimAnneal(moreCities, True, 4)    # the remaining 6 lines run the same sequence of steps as above, although this 
betterSol2 = sa2.anneal()               # time comparing randomized greedy search with an annealing version with underlying 
showPath(betterSol2, moreCities)        # randomized greedy search, using k=4 closest nodes.
# Out:
# Solution ['B', 'C', 'A', 'D', 'E', 'G', 'F'] takes a total of 8.183
# 2.6457513110645907
# 1e-08
# Best fitness obtained:  7.597
# Improvement over greedy heuristic:  0.0716
# ['A', 'D', 'G', 'C']
# Probabilities of closest nodes: [0.4219418892939394, 0.21090723142168627, 0.19841483499553259, 0.16873604428884176]
# Closest node selected: D
# ['C', 'A', 'B', 'F']
# Probabilities of closest nodes: [0.5412176946698192, 0.2706905958948699, 0.1353044236674548, 0.052787285767856205]
# Closest node selected: C
# ['A', 'B', 'F', 'G']
# Probabilities of closest nodes: [0.4351821701468532, 0.4351821701468532, 0.06962914722349652, 0.060006512482797154]
# Closest node selected: B
# ['A', 'F', 'G']
# Probabilities of closest nodes: [0.5586138272569583, 0.26268373246108123, 0.1787024402819605]
# Closest node selected: A
# ['F', 'G']
# Probabilities of closest nodes: [0.5, 0.5]
# Closest node selected: F
# ['G']
# Probabilities of closest nodes: [1.0]
# Closest node selected: G
# Solution ['E', 'D', 'C', 'B', 'A', 'F', 'G'] takes a total of 7.924
# ['A', 'D', 'G', 'C']
# Probabilities of closest nodes: [0.4219418892939394, 0.21090723142168627, 0.19841483499553259, 0.16873604428884176]
# Closest node selected: A
# ['C', 'B', 'D', 'F']
# Probabilities of closest nodes: [0.4332909900942135, 0.21671094175151576, 0.21671094175151576, 0.13328712640275497]
# Closest node selected: C
# ['B', 'D', 'F', 'G']
# Probabilities of closest nodes: [0.4351821701468532, 0.4351821701468532, 0.06962914722349652, 0.060006512482797154]
# Closest node selected: B
# ['D', 'F', 'G']
# Probabilities of closest nodes: [0.3874815126625949, 0.3645303192333444, 0.24798816810406074]
# Closest node selected: F
# ['G', 'D']
# Probabilities of closest nodes: [0.9535138909439373, 0.04648610905606272]
# Closest node selected: G
# ['D']
# Probabilities of closest nodes: [1.0]
# Closest node selected: D
# 2.6457513110645907
# 1e-08
# Best fitness obtained:  7.597
# Improvement over randomized greedy heuristic:  0.1905

# %% [markdown]
# **9. Moving toward a larger example**
# There are a set of coordinates defined in the file *coord.txt* (available in the Jupyter Notebooks module in Brightspace). This data file is also from the github https://github.com/chncyhn/simulated-annealing-tsp.  It contains a larger example with 45 cities, to test.  Here is the beginning of the file:
#
# 1 0 0
# 2 3 5
# 3 2.5 9
# 4 48 16
# 5 48 17
# 6 69 16
# ...
#
# Make sure to put the file *coord.txt* in the same repertory as your notebook or modify the path below when opening the file to read.  We will assume the first number is the label, and the other two numbers are the coordinates.

# %%
# reading the coordinates
manyCities = {}
with open('coord.txt','r') as f:
    i = 0
    for line in f.readlines():
        line = [float(x.replace('\n','')) for x in line.split(' ')]
        label = str(int(line[0]))
        manyCities[label] = (line[1], line[2])
        i += 1

# %% [markdown]
# Show the nodes from that larger set of cities.

# %%
showNodes(manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# %% [markdown]
# Testing the annealing process with the larger example. The steps are the same as the ones you had to comment in Question 4. Look at the additional step *plot_learning*, it shows the value of the fitness function as the annealing process occurs.  Run it multiple times, it is a probabilistic approach, so the result might be slightly different each time.

# %%
firstSol = greedy_solution(manyCities)
distances = distDict(manyCities)
print('Solution {} takes a total of {}'.format(firstSol,totalDist(firstSol, distances)))
showPath(firstSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

sa = SimAnneal(manyCities, False)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

secondSol = randomized_greedy_solution(manyCities, 3)
print('Solution {} takes a total of {}'.format(secondSol,totalDist(secondSol, distances)))
showPath(firstSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

sa2 = SimAnneal(manyCities, True, 4)
betterSol2 = sa2.anneal()
sa2.plot_learning()
showPath(betterSol2, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])
# Out:
# Solution ['35', '41', '40', '42', '31', '32', '33', '34', '30', '28', '7', '6', '8', '36', '4', '5', '37', '43', '39', '38', '2', '16', '10', '25', '1', '17', '3', '11', '18', '19', '12', '13', '15', '14', '21', '22', '9', '20', '26', '27', '23', '24', '45', '44', '29'] takes a total of 594.916
# 6.708203932499369
# 1e-08
# Best fitness obtained:  523.784
# Improvement over greedy heuristic:  0.1344
# ['5', '36', '8']
# Probabilities of closest nodes: [0.9855975592639225, 0.010683286639153619, 0.0037191540969239334]
# Closest node selected: 5
# ['36', '8', '35']
# Probabilities of closest nodes: [0.5803701388626821, 0.2309718717826046, 0.1886579893547134]
# Closest node selected: 36
# ['8', '35', '32']
# Probabilities of closest nodes: [0.46051015058854844, 0.3233864795481409, 0.21610336986331066]
# Closest node selected: 8
# ['6', '7', '28']
# Probabilities of closest nodes: [0.5355915604189271, 0.4047004618127208, 0.05970797776835218]
# Closest node selected: 7
# ['6', '28', '30']
# Probabilities of closest nodes: [0.9925803962430038, 0.005839070785142422, 0.0015805329718539892]
# Closest node selected: 6
# ['28', '30', '35']
# Probabilities of closest nodes: [0.6584829188137473, 0.19460602510030192, 0.14691105608595093]
# Closest node selected: 28
# ['30', '34', '33']
# Probabilities of closest nodes: [0.7061873770117799, 0.1595897995246682, 0.13422282346355188]
# Closest node selected: 33
# ['32', '35', '42']
# Probabilities of closest nodes: [0.9625572100441144, 0.022639327825642663, 0.014803462130242957]
# Closest node selected: 32
# ['35', '42', '31']
# Probabilities of closest nodes: [0.4965590678993551, 0.2611208665486926, 0.24232006555195235]
# Closest node selected: 35
# ['41', '40', '42']
# Probabilities of closest nodes: [0.4694811189722973, 0.40188861766658746, 0.12863026336111535]
# Closest node selected: 41
# ['40', '42', '31']
# Probabilities of closest nodes: [0.9930806986455647, 0.003863751020000157, 0.003055550334435161]
# Closest node selected: 40
# ['42', '31', '43']
# Probabilities of closest nodes: [0.4300173954022642, 0.3408746481649126, 0.22910795643282317]
# Closest node selected: 42
# ['31', '43', '44']
# Probabilities of closest nodes: [0.9923359645440705, 0.004410382064640313, 0.003253653391289142]
# Closest node selected: 31
# ['43', '44', '45']
# Probabilities of closest nodes: [0.37942954185030686, 0.3170375694254786, 0.3035328887242146]
# Closest node selected: 44
# ['45', '43', '39']
# Probabilities of closest nodes: [0.9938857685846065, 0.0036541790192037423, 0.002460052396189714]
# Closest node selected: 45
# ['43', '39', '9']
# Probabilities of closest nodes: [0.4231645996362048, 0.29002652233758763, 0.2868088780262077]
# Closest node selected: 9
# ['22', '21', '20']
# Probabilities of closest nodes: [0.3759729344340555, 0.36346743769387313, 0.2605596278720715]
# Closest node selected: 20
# ['26', '21', '22']
# Probabilities of closest nodes: [0.3472894422529747, 0.33307501418863267, 0.31963554355839263]
# Closest node selected: 26
# ['21', '27', '22']
# Probabilities of closest nodes: [0.34099646266701156, 0.32978213859333927, 0.32922139873964906]
# Closest node selected: 27
# ['23', '24', '21']
# Probabilities of closest nodes: [0.7139697110572873, 0.28551899643680245, 0.000511292505910258]
# Closest node selected: 23
# ['24', '21', '22']
# Probabilities of closest nodes: [0.9993250984400606, 0.0003401419102509394, 0.00033475964968854353]
# Closest node selected: 24
# ['21', '22', '11']
# Probabilities of closest nodes: [0.3608975076195868, 0.35525037476132987, 0.28385211761908347]
# Closest node selected: 21
# ['22', '1', '25']
# Probabilities of closest nodes: [0.9953091263236524, 0.0023472585364141493, 0.0023436151399334557]
# Closest node selected: 22
# ['1', '25', '10']
# Probabilities of closest nodes: [0.3734613992980637, 0.372794206221271, 0.2537443944806654]
# Closest node selected: 25
# ['1', '10', '16']
# Probabilities of closest nodes: [0.9999736049106274, 1.3829514441376279e-05, 1.2565574931200119e-05]
# Closest node selected: 1
# ['10', '16', '2']
# Probabilities of closest nodes: [0.4716752187454873, 0.42771743735004747, 0.10060734390446502]
# Closest node selected: 16
# ['10', '2', '3']
# Probabilities of closest nodes: [0.8692686663842684, 0.10867105949421624, 0.022060274121515375]
# Closest node selected: 10
# ['2', '3', '17']
# Probabilities of closest nodes: [0.6912059662656325, 0.17549029357527463, 0.1333037401590931]
# Closest node selected: 17
# ['3', '2', '11']
# Probabilities of closest nodes: [0.6049447729061246, 0.29879529352831774, 0.09625993356555765]
# Closest node selected: 3
# ['2', '11', '18']
# Probabilities of closest nodes: [0.8892621671553451, 0.058621389398688314, 0.05211644344596664]
# Closest node selected: 2
# ['11', '38', '39']
# Probabilities of closest nodes: [0.36826910003530783, 0.3348614045249196, 0.2968694954397724]
# Closest node selected: 11
# ['18', '19', '12']
# Probabilities of closest nodes: [0.543069756683797, 0.41925733134341436, 0.03767291197278852]
# Closest node selected: 18
# ['19', '12', '13']
# Probabilities of closest nodes: [0.8078531959635076, 0.11254362201647167, 0.07960318202002059]
# Closest node selected: 13
# ['15', '14', '12']
# Probabilities of closest nodes: [0.5537309011268946, 0.44301165601020104, 0.003257442862904444]
# Closest node selected: 15
# ['14', '12', '19']
# Probabilities of closest nodes: [0.992565253731412, 0.0064285514757304995, 0.001006194792857511]
# Closest node selected: 14
# ['12', '19', '38']
# Probabilities of closest nodes: [0.8260556583105372, 0.12584276813288708, 0.048101573556575794]
# Closest node selected: 38
# ['39', '37', '43']
# Probabilities of closest nodes: [0.9453736506025078, 0.029081494741726124, 0.02554485465576628]
# Closest node selected: 39
# ['43', '37', '34']
# Probabilities of closest nodes: [0.49835571227782127, 0.48895362822930966, 0.012690659492869029]
# Closest node selected: 43
# ['37', '34', '19']
# Probabilities of closest nodes: [0.9624648071176879, 0.024561190960707302, 0.01297400192160488]
# Closest node selected: 37
# ['34', '19', '30']
# Probabilities of closest nodes: [0.4635856619219235, 0.28191710783595264, 0.2544972302421238]
# Closest node selected: 34
# ['30', '29', '19']
# Probabilities of closest nodes: [0.8879776731836938, 0.059733296919295076, 0.05228902989701117]
# Closest node selected: 30
# ['29', '19', '12']
# Probabilities of closest nodes: [0.4081717511578946, 0.3202421796119199, 0.27158606923018547]
# Closest node selected: 12
# ['19', '29']
# Probabilities of closest nodes: [0.9790244909070174, 0.02097550909298263]
# Closest node selected: 19
# ['29']
# Probabilities of closest nodes: [1.0]
# Closest node selected: 29
# Solution ['4', '5', '36', '8', '7', '6', '28', '33', '32', '35', '41', '40', '42', '31', '44', '45', '9', '20', '26', '27', '23', '24', '21', '22', '25', '1', '16', '10', '17', '3', '2', '11', '18', '13', '15', '14', '38', '39', '43', '37', '34', '30', '12', '19', '29'] takes a total of 784.884
# ['43', '39', '38', '40']
# Probabilities of closest nodes: [0.39748410580767385, 0.2775189486185547, 0.22629231872834227, 0.09870462684542929]
# Closest node selected: 40
# ['41', '35', '42', '31']
# Probabilities of closest nodes: [0.9870259769962175, 0.006168044974901764, 0.003796496499823195, 0.003009481529057556]
# Closest node selected: 41
# ['35', '42', '31', '32']
# Probabilities of closest nodes: [0.44929794491405184, 0.23945706218743762, 0.18936859612906848, 0.1218763967694421]
# Closest node selected: 32
# ['33', '35', '42', '31']
# Probabilities of closest nodes: [0.9380753503398748, 0.030749246315225798, 0.01616981817997605, 0.015005585164923178]
# Closest node selected: 33
# ['35', '42', '31', '34']
# Probabilities of closest nodes: [0.37705042655112214, 0.24654670640527482, 0.23394751824169904, 0.14245534880190405]
# Closest node selected: 34
# ['30', '31', '42', '35']
# Probabilities of closest nodes: [0.28136829786506123, 0.24479371789788107, 0.24001816968626566, 0.2338198145507921]
# Closest node selected: 30
# ['28', '7', '6', '8']
# Probabilities of closest nodes: [0.4911988211356352, 0.17676101936988645, 0.1699929262371831, 0.16204723325729534]
# Closest node selected: 28
# ['7', '6', '8', '36']
# Probabilities of closest nodes: [0.37435176697759254, 0.3297404995219722, 0.20864808131750268, 0.08725965218293256]
# Closest node selected: 6
# ['7', '8', '36', '4']
# Probabilities of closest nodes: [0.965964995352335, 0.028410266388026215, 0.003434341444780947, 0.0021903968148579028]
# Closest node selected: 7
# ['8', '36', '4', '5']
# Probabilities of closest nodes: [0.7519673464547009, 0.10835846301018388, 0.06991006861116042, 0.06976412192395476]
# Closest node selected: 4
# ['5', '36', '8', '35']
# Probabilities of closest nodes: [0.9823486861740709, 0.01064807080268276, 0.003706894468692375, 0.0032963485545539095]
# Closest node selected: 5
# ['36', '8', '35', '43']
# Probabilities of closest nodes: [0.5361128788899839, 0.2133586599866027, 0.17427150541679046, 0.07625695570662301]
# Closest node selected: 36
# ['8', '35', '42', '31']
# Probabilities of closest nodes: [0.4748193424189468, 0.33343489903530654, 0.09908809173004432, 0.09265766681570226]
# Closest node selected: 35
# ['42', '31', '43', '39']
# Probabilities of closest nodes: [0.3969087014713848, 0.3398010184707085, 0.17107869793923486, 0.09221158211867178]
# Closest node selected: 42
# ['31', '43', '44', '45']
# Probabilities of closest nodes: [0.9892683504932869, 0.004396748224414608, 0.0032435953532696455, 0.0030913059290288104]
# Closest node selected: 31
# ['43', '44', '45', '39']
# Probabilities of closest nodes: [0.3220906546742633, 0.2691272740509913, 0.25766340271660515, 0.15111866855814024]
# Closest node selected: 44
# ['45', '43', '39', '38']
# Probabilities of closest nodes: [0.9916954332897157, 0.003646125903309941, 0.0024546309083679006, 0.002203809898606557]
# Closest node selected: 45
# ['43', '39', '9', '38']
# Probabilities of closest nodes: [0.3353714827060167, 0.22985529721542564, 0.227305211162727, 0.2074680089158307]
# Closest node selected: 39
# ['38', '43', '2', '10']
# Probabilities of closest nodes: [0.9531987778794797, 0.03665146213864659, 0.005151075488749909, 0.004998684493123931]
# Closest node selected: 38
# ['43', '2', '10', '16']
# Probabilities of closest nodes: [0.6083852581986297, 0.13724378834521614, 0.13001042074492167, 0.12436053271123244]
# Closest node selected: 2
# ['16', '3', '10', '25']
# Probabilities of closest nodes: [0.3959450792242144, 0.24363130126800273, 0.24363130126800273, 0.1167923182397802]
# Closest node selected: 16
# ['10', '25', '1', '3']
# Probabilities of closest nodes: [0.746976639282284, 0.1173233499146674, 0.11674326007432619, 0.01895675072872236]
# Closest node selected: 25
# ['1', '10', '17', '3']
# Probabilities of closest nodes: [0.9999838429379551, 1.3829656032060357e-05, 1.17889119122744e-06, 1.1485148216543647e-06]
# Closest node selected: 1
# ['10', '17', '3', '22']
# Probabilities of closest nodes: [0.8064126543012982, 0.06879679379618879, 0.06702599916838392, 0.05776455273412907]
# Closest node selected: 10
# ['3', '17', '22', '21']
# Probabilities of closest nodes: [0.38480683912573077, 0.29230215443371754, 0.16527412513465223, 0.15761688130589935]
# Closest node selected: 3
# ['17', '11', '18', '22']
# Probabilities of closest nodes: [0.8268006485270907, 0.06792451268884575, 0.06038724193429441, 0.04488759684976914]
# Closest node selected: 11
# ['18', '19', '17', '21']
# Probabilities of closest nodes: [0.38785730240977684, 0.29943117905028116, 0.2476349173210349, 0.06507660121890706]
# Closest node selected: 21
# ['22', '9', '20', '17']
# Probabilities of closest nodes: [0.9971596516440332, 0.0010699611063959167, 0.0010217452956459855, 0.0007486419539247948]
# Closest node selected: 22
# ['9', '20', '17', '26']
# Probabilities of closest nodes: [0.3477112972721126, 0.30804587402582095, 0.23714348081887734, 0.10709934788318916]
# Closest node selected: 9
# ['20', '17', '43', '26']
# Probabilities of closest nodes: [0.5152494279027697, 0.16983439921423768, 0.16337231927843748, 0.151543853604555]
# Closest node selected: 17
# ['18', '19', '43', '20']
# Probabilities of closest nodes: [0.5584946778036808, 0.24367212061735996, 0.101189963968052, 0.09664323761090722]
# Closest node selected: 18
# ['19', '12', '13', '15']
# Probabilities of closest nodes: [0.7484453956124768, 0.10426740418265816, 0.07374933386000691, 0.07353786634485798]
# Closest node selected: 13
# ['15', '14', '12', '19']
# Probabilities of closest nodes: [0.5534776130165047, 0.4428090132012063, 0.003255952840321689, 0.0004574209419674055]
# Closest node selected: 14
# ['15', '12', '19', '43']
# Probabilities of closest nodes: [0.9924316200591069, 0.006320769155414761, 0.0009629170616338092, 0.0002846937238444996]
# Closest node selected: 15
# ['12', '19', '43', '20']
# Probabilities of closest nodes: [0.8076092259844867, 0.1264067342257589, 0.03700338269557625, 0.02898065709417819]
# Closest node selected: 12
# ['19', '26', '20', '43']
# Probabilities of closest nodes: [0.6801680771841311, 0.11299815516609678, 0.10495214076520709, 0.10188162688456502]
# Closest node selected: 19
# ['26', '20', '43', '27']
# Probabilities of closest nodes: [0.3548486942508391, 0.32079558559437293, 0.1899017617773121, 0.13445395837747592]
# Closest node selected: 20
# ['26', '27', '23', '24']
# Probabilities of closest nodes: [0.6925961455384683, 0.10862583586639163, 0.10167232478637267, 0.09710569380876757]
# Closest node selected: 26
# ['27', '23', '24', '43']
# Probabilities of closest nodes: [0.3377202236849099, 0.3051368539100808, 0.28903567440796113, 0.06810724799704827]
# Closest node selected: 23
# ['24', '27', '43', '8']
# Probabilities of closest nodes: [0.6665127223296898, 0.33335703498941177, 8.821024836678945e-05, 4.203243253162664e-05]
# Closest node selected: 24
# ['27', '43', '8', '29']
# Probabilities of closest nodes: [0.9988228812521238, 0.000647124882451572, 0.0003103691364953456, 0.0002196247289293231]
# Closest node selected: 27
# ['43', '8', '29']
# Probabilities of closest nodes: [0.5554301899518865, 0.2621733601029795, 0.18239644994513401]
# Closest node selected: 43
# ['8', '29']
# Probabilities of closest nodes: [0.8918661137356726, 0.1081338862643274]
# Closest node selected: 8
# ['29']
# Probabilities of closest nodes: [1.0]
# Closest node selected: 29
# 6.708203932499369
# 1e-08
# Best fitness obtained:  526.086
# Improvement over randomized greedy heuristic:  0.2737

# %% [markdown]
# **(TO DO) Q6 - 2 marks**
# Try the annealing again, but provide a different temperature schedule, by changing alpha, and the starting and stopping temperatures.  These are all parameters to the class which can be set.  Try also changing the number of iterations to do.  Explore 4 variations below.

# %%
# (TO DO) Look at this line from the SimAnneal class above
# def __init__(self, nodes, randomizedGreedy, k=4, T=-1, alpha=-1, stopping_T=-1, stopping_iter=-1):
# This means that parameters k, T, alpha, stopping_T and stopping_iter all have defaults, but could be changed
# For example, calling SimAnneal(manyCities, False, stopping_iter=100) means that I set a maximum of 100 iterations for a 
# Greedy solution. Calling  SimAnneal(manyCities, True, k=3, stopping_iter=100) is the same for a randomized greedy solution
# with k = 3.
# Try four variations and look at the differences
# The key point of this question is to use different parameters to understand how they work
# What you need to do is create and run these four different examples

# Test 1 (Use a Greedy solution, see comment above) ...
sa = SimAnneal(manyCities, False, alpha=0.5)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 2 (Use a Randomized Greedy solution, see comment above)...
sa = SimAnneal(manyCities, True, k=2)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 3 (Use a Greedy solution, see comment above)...
sa = SimAnneal(manyCities, False, stopping_iter=10)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])

# Test 4 (Use a Randomized Greedy solution, see comment above)...
sa = SimAnneal(manyCities, True, k=5, T=20)
betterSol = sa.anneal()
sa.plot_learning()
showPath(betterSol, manyCities, size=(15,15), xLim=[-75,100], yLim=[-110,60])
# Out:
# 6.708203932499369
# 1e-08
# Best fitness obtained:  626.24
# Improvement over greedy heuristic:  0.0014
# ['3', '2']
# Probabilities of closest nodes: [0.669379167057221, 0.330620832942779]
# Closest node selected: 3
# ['2', '16']
# Probabilities of closest nodes: [0.7519291262759196, 0.24807087372408035]
# Closest node selected: 2
# ['16', '10']
# Probabilities of closest nodes: [0.6190739547315609, 0.38092604526843904]
# Closest node selected: 16
# ['10', '25']
# Probabilities of closest nodes: [0.8642562173075158, 0.1357437826924842]
# Closest node selected: 10
# ['25', '1']
# Probabilities of closest nodes: [0.500743217723989, 0.4992567822760111]
# Closest node selected: 1
# ['25', '22']
# Probabilities of closest nodes: [0.9999990122866015, 9.87713398442874e-07]
# Closest node selected: 25
# ['22', '21']
# Probabilities of closest nodes: [0.511434087557248, 0.48856591244275205]
# Closest node selected: 21
# ['22', '9']
# Probabilities of closest nodes: [0.9989281412886081, 0.0010718587113919065]
# Closest node selected: 22
# ['9', '20']
# Probabilities of closest nodes: [0.5302439873953512, 0.4697560126046489]
# Closest node selected: 20
# ['26', '9']
# Probabilities of closest nodes: [0.5814037893440092, 0.41859621065599095]
# Closest node selected: 9
# ['45', '44']
# Probabilities of closest nodes: [0.5038739997573104, 0.4961260002426897]
# Closest node selected: 45
# ['44', '31']
# Probabilities of closest nodes: [0.9967319331854458, 0.003268066814554098]
# Closest node selected: 44
# ['43', '31']
# Probabilities of closest nodes: [0.5177430705844995, 0.4822569294155005]
# Closest node selected: 43
# ['37', '39']
# Probabilities of closest nodes: [0.5842437889467144, 0.41575621105328553]
# Closest node selected: 39
# ['38', '37']
# Probabilities of closest nodes: [0.9636458886461559, 0.03635411135384405]
# Closest node selected: 38
# ['37', '40']
# Probabilities of closest nodes: [0.8470716681162063, 0.15292833188379376]
# Closest node selected: 37
# ['40', '41']
# Probabilities of closest nodes: [0.5165909353903995, 0.48340906460960054]
# Closest node selected: 40
# ['41', '35']
# Probabilities of closest nodes: [0.993789687776553, 0.006210312223447033]
# Closest node selected: 41
# ['35', '42']
# Probabilities of closest nodes: [0.6523334716720932, 0.34766652832790673]
# Closest node selected: 35
# ['32', '33']
# Probabilities of closest nodes: [0.5822313695810746, 0.41776863041892537]
# Closest node selected: 32
# ['33', '42']
# Probabilities of closest nodes: [0.9830548597850828, 0.016945140214917078]
# Closest node selected: 33
# ['42', '31']
# Probabilities of closest nodes: [0.5131106551518206, 0.4868893448481794]
# Closest node selected: 31
# ['42', '34']
# Probabilities of closest nodes: [0.998198166930713, 0.0018018330692870096]
# Closest node selected: 42
# ['34', '36']
# Probabilities of closest nodes: [0.5049187716211111, 0.4950812283788889]
# Closest node selected: 36
# ['4', '5']
# Probabilities of closest nodes: [0.5398684576566551, 0.4601315423433448]
# Closest node selected: 5
# ['4', '8']
# Probabilities of closest nodes: [0.9963368093398349, 0.0036631906601649806]
# Closest node selected: 4
# ['8', '6']
# Probabilities of closest nodes: [0.624640724466754, 0.3753592755332459]
# Closest node selected: 8
# ['6', '7']
# Probabilities of closest nodes: [0.5696013023143359, 0.43039869768566413]
# Closest node selected: 7
# ['6', '28']
# Probabilities of closest nodes: [0.9941516857613738, 0.005848314238626333]
# Closest node selected: 6
# ['28', '30']
# Probabilities of closest nodes: [0.7718807323801058, 0.22811926761989423]
# Closest node selected: 28
# ['30', '34']
# Probabilities of closest nodes: [0.8156687380428426, 0.18433126195715752]
# Closest node selected: 30
# ['34', '29']
# Probabilities of closest nodes: [0.9472387092443489, 0.052761290755651086]
# Closest node selected: 34
# ['11', '18']
# Probabilities of closest nodes: [0.5041285360234561, 0.495871463976544]
# Closest node selected: 18
# ['11', '19']
# Probabilities of closest nodes: [0.5541832513330687, 0.4458167486669314]
# Closest node selected: 19
# ['11', '12']
# Probabilities of closest nodes: [0.8652832329750489, 0.13471676702495097]
# Closest node selected: 11
# ['26', '12']
# Probabilities of closest nodes: [0.5025779064677511, 0.49742209353224875]
# Closest node selected: 26
# ['27', '23']
# Probabilities of closest nodes: [0.5253426235087336, 0.4746573764912665]
# Closest node selected: 27
# ['23', '24']
# Probabilities of closest nodes: [0.7143349451614582, 0.2856650548385419]
# Closest node selected: 23
# ['24', '12']
# Probabilities of closest nodes: [0.9998681785091365, 0.0001318214908635611]
# Closest node selected: 24
# ['12', '13']
# Probabilities of closest nodes: [0.5585705704275663, 0.44142942957243375]
# Closest node selected: 13
# ['15', '14']
# Probabilities of closest nodes: [0.5555405427027759, 0.44445945729722425]
# Closest node selected: 14
# ['15', '12']
# Probabilities of closest nodes: [0.9936713351340407, 0.006328664865959209]
# Closest node selected: 15
# ['12', '29']
# Probabilities of closest nodes: [0.9938652173478612, 0.006134782652138743]
# Closest node selected: 12
# ['29']
# Probabilities of closest nodes: [1.0]
# Closest node selected: 29
# 6.708203932499369
# 1e-08
# Best fitness obtained:  527.399
# Improvement over randomized greedy heuristic:  0.2718
# 6.708203932499369
# 1e-08
# Best fitness obtained:  573.645
# Improvement over greedy heuristic:  0.0
# ['34', '30', '33', '31', '32']
# Probabilities of closest nodes: [0.24442236611250487, 0.20238693743787206, 0.18690119688377715, 0.18424599062507346, 0.18204350894077248]
# Closest node selected: 33
# ['32', '35', '42', '31', '41']
# Probabilities of closest nodes: [0.9379039128962869, 0.022059482731461643, 0.014424311522980075, 0.013687191089866992, 0.011925101759404574]
# Closest node selected: 35
# ['41', '40', '32', '42', '31']
# Probabilities of closest nodes: [0.34176139249655557, 0.29255705512270747, 0.19187993721472957, 0.09363711584339018, 0.0801644993226172]
# Closest node selected: 41
# ['40', '42', '31', '32', '43']
# Probabilities of closest nodes: [0.9892918581446983, 0.003849009885296999, 0.0030438926787427953, 0.0019590295298234557, 0.001856209761438661]
# Closest node selected: 40
# ['42', '31', '43', '32', '37']
# Probabilities of closest nodes: [0.3090170713883895, 0.24495773104232502, 0.1646404784681345, 0.146597047598812, 0.13478767150233892]
# Closest node selected: 42
# ['31', '32', '43', '44', '45']
# Probabilities of closest nodes: [0.9809025295900912, 0.008456573890213032, 0.004359566798178183, 0.003216165649494769, 0.0030651640720227246]
# Closest node selected: 31
# ['32', '43', '44', '45', '37']
# Probabilities of closest nodes: [0.37289256613963867, 0.19103162654641928, 0.1596191015289115, 0.15281989156815864, 0.12363681421687187]
# Closest node selected: 43
# ['37', '39', '38', '44', '45']
# Probabilities of closest nodes: [0.40501201892203964, 0.28821232780521067, 0.20253713753594302, 0.05510067155440041, 0.04913784418240622]
# Closest node selected: 37
# ['39', '38', '4', '44', '5']
# Probabilities of closest nodes: [0.4707036720036702, 0.3838174867045241, 0.04939999358546574, 0.04901101016778256, 0.047067837538557526]
# Closest node selected: 39
# ['38', '2', '10', '16', '44']
# Probabilities of closest nodes: [0.9798201419193366, 0.005294937040993877, 0.005138290001124976, 0.004897621181182385, 0.004849009857362327]
# Closest node selected: 38
# ['2', '10', '16', '3', '25']
# Probabilities of closest nodes: [0.22474150329888082, 0.2128966108778515, 0.203644721626822, 0.1948828355707475, 0.16383432862569816]
# Closest node selected: 16
# ['10', '25', '1', '2', '3']
# Probabilities of closest nodes: [0.6831794305362998, 0.1073030870956375, 0.10677254112412628, 0.08540723416368456, 0.01733770708025177]
# Closest node selected: 1
# ['25', '10', '2', '17', '3']
# Probabilities of closest nodes: [0.9999809479790766, 1.378856335433431e-05, 2.9410719075461033e-06, 1.1763319248204605e-06, 1.1460537368694571e-06]
# Closest node selected: 25
# ['10', '2', '17', '3', '22']
# Probabilities of closest nodes: [0.6882762472701114, 0.14682499149263922, 0.05867122097301577, 0.057159445582002553, 0.049068094682231264]
# Closest node selected: 10
# ['2', '3', '17', '22', '21']
# Probabilities of closest nodes: [0.6024874496617216, 0.1529655480084809, 0.1161937748783204, 0.06569853898720338, 0.06265468846427377]
# Closest node selected: 17
# ['3', '2', '11', '18', '22']
# Probabilities of closest nodes: [0.548297857510856, 0.2708161581244491, 0.08724617138947138, 0.06002053955394911, 0.03361927342127442]
# Closest node selected: 2
# ['3', '22', '21', '11', '18']
# Probabilities of closest nodes: [0.8179057704790643, 0.05268882155162864, 0.05111277049673175, 0.044559898549818844, 0.03373273892275634]
# Closest node selected: 3
# ['11', '18', '22', '21', '19']
# Probabilities of closest nodes: [0.27741578334457767, 0.24663222983963803, 0.1833289242659403, 0.17982962902460212, 0.11279343352524193]
# Closest node selected: 22
# ['21', '9', '20', '11', '26']
# Probabilities of closest nodes: [0.9970658953695402, 0.0011066702318215692, 0.0009804260071338635, 0.0005061403751941198, 0.0003408680163103052]
# Closest node selected: 21
# ['9', '20', '11', '26', '18']
# Probabilities of closest nodes: [0.329478180651825, 0.3146308581561026, 0.15851893893004637, 0.10872954611750747, 0.08864247614451864]
# Closest node selected: 11
# ['18', '19', '20', '26', '12']
# Probabilities of closest nodes: [0.5029901249818716, 0.38831530369085965, 0.038547755676813324, 0.03525423975498515, 0.034892575895470235]
# Closest node selected: 18
# ['19', '12', '13', '15', '14']
# Probabilities of closest nodes: [0.6999566384799097, 0.09751233979466924, 0.06897141210487324, 0.06877364471673905, 0.06478596490380856]
# Closest node selected: 12
# ['13', '15', '14', '19', '26']
# Probabilities of closest nodes: [0.328920351665514, 0.28972311774241283, 0.28490392262339986, 0.08271152026613195, 0.013741087702541463]
# Closest node selected: 13
# ['15', '14', '19', '5', '4']
# Probabilities of closest nodes: [0.5551488705439339, 0.44414610051805853, 0.0004588021508446722, 0.00012408321562579392, 0.0001221435715371068]
# Closest node selected: 15
# ['14', '19', '5', '4', '20']
# Probabilities of closest nodes: [0.998188504754069, 0.00101189526028437, 0.00028609373492252086, 0.00028151394641250175, 0.00023199230431150282]
# Closest node selected: 14
# ['19', '5', '4', '26', '20']
# Probabilities of closest nodes: [0.49091961944394197, 0.14090742847512153, 0.13865073507608947, 0.11491724704440556, 0.1146049699604415]
# Closest node selected: 5
# ['4', '36', '8', '6', '7']
# Probabilities of closest nodes: [0.9830528422212279, 0.009081888718284458, 0.003614350043394972, 0.0022240583002200113, 0.002026860716872796]
# Closest node selected: 4
# ['36', '8', '6', '7', '32']
# Probabilities of closest nodes: [0.5205561514902098, 0.18122031252052515, 0.10889895992241404, 0.09922405232600122, 0.09010052374084976]
# Closest node selected: 8
# ['6', '7', '36', '28', '32']
# Probabilities of closest nodes: [0.45312750273300345, 0.34238946833414474, 0.12811796222172459, 0.05051484911048463, 0.02585021760064252]
# Closest node selected: 6
# ['7', '28', '36', '30', '32']
# Probabilities of closest nodes: [0.9887363266778368, 0.005123313615930586, 0.003515301445712952, 0.0015141284149551596, 0.0011109298455643656]
# Closest node selected: 7
# ['28', '36', '30', '32', '34']
# Probabilities of closest nodes: [0.46567678523244116, 0.2535036914629303, 0.126050452267105, 0.08520726319114003, 0.06956180784638365]
# Closest node selected: 28
# ['30', '36', '34', '32', '44']
# Probabilities of closest nodes: [0.562310869479118, 0.17425266553376134, 0.12707545030108544, 0.10441561253292654, 0.031945402153108794]
# Closest node selected: 34
# ['32', '30', '36', '44', '45']
# Probabilities of closest nodes: [0.43877529763737866, 0.24488123506646342, 0.1614006241355921, 0.07754684465167234, 0.07739599850889327]
# Closest node selected: 44
# ['45', '9', '32', '20', '36']
# Probabilities of closest nodes: [0.995301635691034, 0.002177812931885401, 0.0012488267527714636, 0.0006505310773528474, 0.0006211935469563195]
# Closest node selected: 45
# ['9', '32', '20', '36', '26']
# Probabilities of closest nodes: [0.4405681306253056, 0.24176451345412725, 0.13000287092691487, 0.11969953684444436, 0.06796494814920791]
# Closest node selected: 9
# ['20', '26', '19', '32', '27']
# Probabilities of closest nodes: [0.5952186532441135, 0.17506419913375984, 0.08753316922430761, 0.07947742004782936, 0.06270655834998978]
# Closest node selected: 26
# ['20', '27', '23', '24', '19']
# Probabilities of closest nodes: [0.48929509241853897, 0.15683567253871755, 0.14170410992024418, 0.13422679840976273, 0.07793832671273646]
# Closest node selected: 24
# ['23', '27', '20', '19', '32']
# Probabilities of closest nodes: [0.8326798564122716, 0.16654609728516923, 0.0004989191233682424, 0.00020240449237812622, 7.272268681276223e-05]
# Closest node selected: 23
# ['27', '20', '19', '32', '36']
# Probabilities of closest nodes: [0.9979271002966965, 0.001251721713732857, 0.0004927725284615657, 0.0001774360314350086, 0.00015096942967412542]
# Closest node selected: 27
# ['20', '19', '32', '36', '30']
# Probabilities of closest nodes: [0.5825272507615195, 0.2241680862736785, 0.0791185946063487, 0.06728314271503338, 0.04690292564341987]
# Closest node selected: 20
# ['19', '32', '36', '30']
# Probabilities of closest nodes: [0.5480093078138545, 0.20142313421113994, 0.1581343720170839, 0.09243318595792176]
# Closest node selected: 19
# ['32', '36', '30']
# Probabilities of closest nodes: [0.399398821304314, 0.3986723989912831, 0.20192877970440296]
# Closest node selected: 36
# ['32', '30']
# Probabilities of closest nodes: [0.7950809013771685, 0.20491909862283167]
# Closest node selected: 32
# ['30']
# Probabilities of closest nodes: [1.0]
# Closest node selected: 30
# 20
# 1e-08
# Best fitness obtained:  529.712
# Improvement over randomized greedy heuristic:  0.296

# %% [markdown]
# ***SIGNATURE:***
# My name is --------------------------.
# My student number is -----------------.
# I certify being the author of this assignment.

# %%
print("My name is Charie Kaylan Brady. My student number is 300043672. I certify being the author of this assignment.")
# Out:
# My name is Charie Kaylan Brady. My student number is 300043672. I certify being the author of this assignment.
